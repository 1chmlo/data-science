# %%
# %pip install nbformat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nbformat

# 1. Leer los notebooks
nb1 = nbformat.read("1_obtain.ipynb", as_version=4)
nb2 = nbformat.read("2_scrub.ipynb", as_version=4)
nb3 = nbformat.read("3_explore.ipynb", as_version=4)
nb4 = nbformat.read("4_model.ipynb", as_version=4)

# 2. Agregar las celdas del segundo notebook al primero
nb1.cells.extend(nb2.cells)
nb1.cells.extend(nb3.cells)
nb1.cells.extend(nb4.cells)

# 3. Guardar el resultado en un nuevo archivo
nbformat.write(nb1, "Forecasting_Demanda_Hospitalaria.ipynb")
